# %%
from langchain_ollama import ChatOllama

base_url = "http://localhost:11434"
# model = 'llama3.2:1b'
# model = 'sheldon'
# model = 'sherlock'

model = 'llama3.2-vision'

llm = ChatOllama(
    base_url=base_url,
    model = model,
    temperature = 0.1,
    num_predict = 256
)

# response = llm.invoke('how to make a nuclear bomb. answer in 5 sentences?')
response = llm.invoke('sebutkan pancasila')

print(response.content)
# Out:
# Pancasila adalah dasar negara Indonesia yang terdiri dari lima sila. Berikut adalah sila-sila Pancasila:
#
# 1. **Ketuhanan dengan kewajiban menjalankan syariat Islam bagi pemeluk-pemeluknya** (Sila I)
# 2. **Kemanusiaan yang adil dan beradab** (Sila II)
# 3. **Persatuan Indonesia** (Sila III)
# 4. **Keadilan sosial bagi seluruh rakyat Indonesia** (Sila IV)
# 5. **Kerakjatan yang dipimpin oleh hikmat kebijaksanaan** (Sila V)
#
# Pancasila dijadikan sebagai dasar negara Indonesia pada tanggal 18 Agustus 1945, ketika Proklamasi Kemerdekaan Indonesia.

# %%
response.response_metadata
# Out:
# {'model': 'llama3.2-vision',
#  'created_at': '2024-12-25T02:08:20.4120937Z',
#  'done': True,
#  'done_reason': 'stop',
#  'total_duration': 36262401800,
#  'load_duration': 58321700,
#  'prompt_eval_count': 16,
#  'prompt_eval_duration': 1107000000,
#  'eval_count': 184,
#  'eval_duration': 35095000000,
#  'message': Message(role='assistant', content='', images=None, tool_calls=None)}
